# %%
import pandas as pd

# %%
df_movies = pd.read_csv('archive/movies.csv')
# Out:
# /home/fepas/unb/paa/trab1/env/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df_movies
# Out:
#       imdb_title_id                           title  \
# 0         tt0000009                      Miss Jerry
# 1         tt0000574     The Story of the Kelly Gang
# 2         tt0001892                  Den sorte drøm
# 3         tt0002101                       Cleopatra
# 4         tt0002130                       L'Inferno
# ...             ...                             ...
# 85850     tt9908390                         Le lion
# 85851     tt9911196  De Beentjes van Sint-Hildegard
# 85852     tt9911774       Padmavyuhathile Abhimanyu
# 85853     tt9914286               Sokagin Çocuklari
# 85854     tt9914942      La vida sense la Sara Amat
#
#                        original_title  year date_published  \
# 0                          Miss Jerry  1894     1894-10-09
# 1         The Story of the Kelly Gang  1906     1906-12-26
# 2                      Den sorte drøm  1911     1911-08-19
# 3                           Cleopatra  1912     1912-11-13
# ...

# %%
df_movies.columns
# Out:
# Index(['imdb_title_id', 'title', 'original_title', 'year', 'date_published',
#        'genre', 'duration', 'country', 'language', 'director', 'writer',
#        'production_company', 'actors', 'description', 'avg_vote', 'votes',
#        'budget', 'usa_gross_income', 'worlwide_gross_income', 'metascore',
#        'reviews_from_users', 'reviews_from_critics'],
#       dtype='object')

# %%
df_movies = df_movies[['title','year','genre','actors','description']]

# %%
df_movies['year'] = df_movies['year'].replace('TV Movie 2019', 2019)
# Out:
# /tmp/ipykernel_22607/3684251213.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_movies['year'] = df_movies['year'].replace('TV Movie 2019', 2019)

# %%
df_movies['year'] = pd.to_numeric(df_movies['year'])
# Out:
# /tmp/ipykernel_22607/533989720.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_movies['year'] = pd.to_numeric(df_movies['year'])

# %%
df_movies["year"].unique()
# Out:
# array([1894, 1906, 1911, 1912, 1919, 1913, 1914, 1915, 1916, 1917, 1918,
#        1920, 1921, 1924, 1922, 1923, 1925, 1926, 1935, 1927, 1928, 1983,
#        1929, 1930, 1932, 1931, 1937, 1938, 1933, 1934, 1936, 1940, 1939,
#        1942, 1943, 1941, 1948, 1944, 2001, 1946, 1945, 1947, 1973, 1949,
#        1950, 1952, 1951, 1962, 1953, 1954, 1955, 1961, 1956, 1958, 1957,
#        1959, 1960, 1963, 1965, 1971, 1964, 1966, 1968, 1967, 1969, 1976,
#        1970, 1979, 1972, 1981, 1978, 2000, 1989, 1975, 1974, 1986, 1990,
#        2018, 1977, 1982, 1980, 1993, 1984, 1985, 1988, 1987, 2005, 1991,
#        2002, 1994, 1992, 1995, 2017, 1997, 1996, 2006, 1999, 1998, 2007,
#        2008, 2003, 2004, 2010, 2009, 2011, 2013, 2012, 2016, 2015, 2014,
#        2019, 2020])

# %%
df_movies = df_movies[df_movies['year'] >= 1980]

# %%
df_movies["year"].unique()
# Out:
# array([1983, 2001, 1981, 2000, 1989, 1986, 1990, 2018, 1982, 1980, 1993,
#        1984, 1985, 1988, 1987, 2005, 1991, 2002, 1994, 1992, 1995, 2017,
#        1997, 1996, 2006, 1999, 1998, 2007, 2008, 2003, 2004, 2010, 2009,
#        2011, 2013, 2012, 2016, 2015, 2014, 2019, 2020])

# %%
df_movies = df_movies.sort_values('year')

# %%
df_movies.tail()
# Out:
#                                    title  year                         genre  \
# 85324          Mariyam Vannu Vilakkoothi  2020              Comedy, Thriller
# 84152                          Kill Mode  2020                Action, Sci-Fi
# 70084                            Scooby!  2020  Animation, Adventure, Comedy
# 70101  There's No Such Thing as Vampires  2020                        Horror
# 80707                      Ghosts of War  2020         Horror, Thriller, War
#
#                                                   actors  \
# 85324  Siju Wilson, S.V. Krishna Shankar, Shabareesh ...
# 84152  Dave Mantel, Julia Batelaan, Yasmin Blake, Cyr...
# 70084  Will Forte, Mark Wahlberg, Jason Isaacs, Gina ...
# 70101  Emma Holzer, Aric Cushing, Josh Plasse, Meg Fo...
# 80707  Brenton Thwaites, Kyle Gallner, Alan Ritchson,...
#
#                                              description
# 85324  Three friends, all the way from their school d...
# ...

# %%
actors = []
for index, row in df_movies.iterrows():
    if (type(row['actors']) == str):
        actors_in_movies = row['actors']
        vector = actors_in_movies.split(', ')
        for act in vector:
            actors.append(act)
        
actors_set = set(actors)

# %%
actors_set
# Out:
# {'Carolyn Nicholson',
#  'Agnese De Donato',
#  'Lukas Roberts',
#  'Loloq',
#  'Adam Ild Rohweder',
#  'Lilian Thuram',
#  'Ignacio Cawen',
#  'Ann Merchant',
#  'Bea Melkvi',
#  'Kaza Marie Ayersman',
#  'Mogens von Gadow',
#  'Tiger Ting',
#  'Josef Säterhagen',
#  'Edmund Donovan',
#  'Erin Harth',
#  'Janine Birkett',
#  'Camille Juliette',
#  'Solal Charhon',
#  'Shaun Surplice',
#  'Michael A. Weiss',
#  'Ian Meadows',
#  'Alan Sues',
#  'Roger Miremont',
#  'Gaelle Hersent',
#  'Charlene deGuzman',
#  'Carissa Quintas',
#  'Loren Lott',
#  'Iris Quinn',
#  'Kristian Jøraandstad',
#  'Shin-Jeong Han',
#  'Sakina Asamori',
#  'Anna Colona',
#  'Jeff Fahey',
#  'Udjo',
#  'Sandeep Bose',
#  'Lacey Hanner',
#  'Shiva Rindani',
#  'Jazmin Paradis',
#  'Charlotte Anne Bongaerts',
#  'Gracita Morales',
#  'Titus Tiel Groenestege',
#  'Abbas Ullah',
#  'Julien Graux',
#  'Michael Larsen',
#  'Mary Ann Gilbert',
#  'Nicolas Brites',
#  'Marium Carvell',
#  'Suzuno Nomura',
# ...

# %%
len(actors_set)
# Out:
# 354342
